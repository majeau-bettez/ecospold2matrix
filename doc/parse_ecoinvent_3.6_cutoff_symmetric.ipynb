# %%
# Basic imports
import pandas as pd
import numpy as np
import sys
import gzip
import pickle

# %%
# import of module
sys.path.append('/home/bill/software/ecospold2matrix/ecospold2matrix/')
import ecospold2matrix as e2m

# %%
# paths
ecospold_dir = '/mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_cut-off_ecoSpold02'
project_name = 'ecoinvent_3-6_cutoff_symm'
out_dir = '/mnt/collection/data/ecoinvent/3.6/'
characterisation_file = '/mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_LCIA_implementation/LCIA_implementation_3.6.xlsx'

# %%
# Define parser object with most parsing parameters
parser = e2m.Ecospold2Matrix(sys_dir=ecospold_dir, 
                             project_name=project_name, 
                             out_dir=out_dir, 
                             characterisation_file=characterisation_file, 
                             float32=False,
                             nan2null=True,
                             PRO_properties=('dry mass', 'wet mass', 'iron content', 'carbon content'))
# Out:
# 2020-05-21 13:29:15,593 - ecoinvent_3-6_cutoff_symm - INFO - Ecospold2Matrix Processing
# 2020-05-21 13:29:15,600 - ecoinvent_3-6_cutoff_symm - INFO - Project name: ecoinvent_3-6_cutoff_symm
# 2020-05-21 13:29:15,601 - ecoinvent_3-6_cutoff_symm - INFO - Unit process and Master data directory: /mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_cut-off_ecoSpold02
# 2020-05-21 13:29:15,602 - ecoinvent_3-6_cutoff_symm - INFO - Data saved in: /mnt/collection/data/ecoinvent/3.6
# 2020-05-21 13:29:15,603 - ecoinvent_3-6_cutoff_symm - INFO - Replace Not-a-Number instances with 0.0 in all matrices
# 2020-05-21 13:29:15,603 - ecoinvent_3-6_cutoff_symm - INFO - Pickle intermediate results to files
# 2020-05-21 13:29:15,604 - ecoinvent_3-6_cutoff_symm - INFO - Order processes based on: ISIC, activityName
# 2020-05-21 13:29:15,604 - ecoinvent_3-6_cutoff_symm - INFO - Order elementary exchanges based on: comp, name, subcomp
# 2020-05-21 13:29:15,853 - ecoinvent_3-6_cutoff_symm - WARNING - obs2char_subcomps constraints temporarily relaxed because not full recipe parsed

# %%
# If we want to see the list of all properties we have access to
parser.get_all_properties()
# Out:
# ['amount 1 of flow in kg',
#  'EcoSpold01Allocation_other_78',
#  'mass concentration, titanium',
#  'EcoSpold01Allocation_undefined_28',
#  'molding efficiency',
#  'ash content',
#  'EcoSpold01Allocation_undefined_153',
#  'silver content',
#  'concentration, potassium',
#  'UVEK_absolute_amount_1',
#  'carbon content, non-fossil',
#  'thallium content',
#  'EcoSpold01Allocation_undefined_72',
#  'concentration of amount 5',
#  'EcoSpold01Allocation_other_101',
#  'EcoSpold01Allocation_undefined_169',
#  'EcoSpold01Allocation_other_51',
#  'EcoSpold01Allocation_undefined_32',
#  'EcoSpold01Allocation_undefined_105',
#  'mass concentration, dissolved nitrite NO2 as N',
#  'EcoSpold01Allocation_physical_1',
#  'alloy additives',
#  'EcoSpold01Allocation_undefined_21',
#  'EcoSpold01Allocation_other_16',
#  'nitrogen oxides emissions tier T2 for hp < 175',
#  'mass concentration, nickel',
#  'EcoSpold01Allocation_other_124',
#  'radium content',
#  'EcoSpold01Allocation_other_86',
#  'carbon monoxide emissions tier T0 for hp < 100',
#  'nitrogen oxides emissions tier T3B-T4-T4A for hp < 100',
#  'EcoSpold01Allocation_other_102',
#  'lifetime',
#  'nitrogen oxides emissions tier T4A-T4B for hp < 11',
#  'EcoSpold01Allocation_other_106',
#  'EcoSpold01Allocation_other_115',
#  'mass concentration, sulfur',
#  'nitrogen oxides emissions tier T1 for hp < 300',
#  'SAM_activityLink_9',
#  'palladium content',
#  'EcoSpold01Allocation_other_36',
#  'carbon monoxide emissions tier T0-T1 for hp < 50',
#  'fat (total lipid) content',
#  'EcoSpold01Allocation_undefined_91',
#  'concentration, magnesium',
#  'neon content',
#  'mass concentration, Kjeldahl Nitrogen as N',
#  'fuel input in physical units, m3',
#  'krypton content',
#  'mass concentration, aluminium',
#  'EcoSpold01Allocation_undefined_62',
#  'MARKET_OVERWRITE_AMOUNT_APOS',
#  'zinc content',
#  'EcoSpold01Allocation_other_85',
#  'EcoSpold01Allocation_other_79',
#  'amount of non-specified waste to recycling',
#  'mass concentration, krypton',
#  'lower heating value',
#  'EcoSpold01Allocation_undefined_49',
#  'non-process water, net',
#  'nitrogen oxides emissions tier T4A-T4B for hp < 25',
#  'mass concentration, tellurium',
#  'EcoSpold01Allocation_other_139',
#  'amount of non-specified waste to landfill',
#  'ruthenium content',
#  'amount of flow 4 in kg',
#  'EcoSpold01Allocation_undefined_108',
#  'EcoSpold01Allocation_other_105',
#  'EcoSpold01Allocation_undefined_48',
#  'height, external',
#  'EcoSpold01Allocation_other_11',
#  'EcoSpold01Allocation_undefined_33',
#  'steel, fraction',
#  'apparent wood density',
#  'EcoSpold01Allocation_undefined_73',
#  'concentration, silver',
#  'carbon monoxide emissions tier T4A for hp < 50',
#  'literFuel_Input',
#  'mass concentration, thallium',
#  'EcoSpold01Allocation_undefined_74',
#  'mass concentration, osmium',
#  'EcoSpold01Allocation_other_52',
#  'EcoSpold01Allocation_undefined_112',
#  'EcoSpold01Allocation_other_127',
#  'basic density',
#  'EcoSpold01Allocation_other_74',
#  'landfilled waste carbon',
#  'nitrogen oxides emissions tier T1 for hp < 100',
#  'EcoSpold01Allocation_other_64',
#  'EcoSpold01Allocation_undefined_68',
#  'concentration of amount 3',
#  'amount of exchange in kg 1',
#  'fuel input, fraction',
#  'gas density',
#  'EcoSpold01Allocation_other_130',
#  'nitrogen oxides emissions tier T2 for hp < 300',
#  'mass concentration, zirconium',
#  'lithium content',
#  'yearly_distributed_amount',
#  'utilization rate',
#  'EcoSpold01Allocation_undefined_95',
#  'platinum content',
#  'titanium content',
#  'EcoSpold01Allocation_other_117',
#  'EcoSpold01Allocation_undefined_148',
#  'heat of fuel used',
#  'gold content',
#  'EcoSpold01Allocation_physical_12',
#  'mass concentration, xenon',
#  'EcoSpold01Allocation_other_14',
#  'basic wood density',
#  'mass concentration, scandium',
#  'gadolinium content',
#  'dross sent to landfill',
#  'amount from wellenstoff production in kg',
#  'mass concentration, fluorine',
#  'Organic Carbon content of soil',
#  'amount of exchange 3',
#  'EcoSpold01Allocation_undefined_109',
#  'yield',
#  'amount of exchange in m³ 2',
#  'EcoSpold01Allocation_undefined_128',
#  'mass concentration, silicon',
#  'EcoSpold01Allocation_other_33',
#  'benzofluoranthene content',
#  'EcoSpold01Allocation_other_122',
#  'EcoSpold01Allocation_other_88',
#  'EcoSpold01Allocation_physical_11',
#  'EcoSpold01Allocation_other_32',
#  'Slope length',
#  'mass concentration, particulate phophorus',
#  'EcoSpold01Allocation_undefined_163',
#  'prop',
#  'EcoSpold01Allocation_undefined_154',
#  'mass concentration, lithium',
#  'maximum gross weight',
#  'SAM_activityLink_8_scaling_factor',
#  'capacity [MW]',
#  'UVEK_link_1',
#  'nitrogen content',
#  'nitrogen oxides emissions tier T2-T4A-T4B for hp < 11',
#  'amount of exchange in liters 2',
#  'Soil organic carbon',
#  'amount 4 of flow in kg',
#  'EcoSpold01Allocation_other_7',
#  'nitrogen oxides emissions tier T1 for hp < 600',
#  'EcoSpold01Allocation_undefined_136',
#  'low heating value of hardcoal in Colombia',
#  'nitrogen oxides emissions tier T4 for hp >= 750',
#  'Crop factor',
#  'fuel input in m3',
#  'nitrogen oxides emissions tier T2-T3-T4-T4N for hp < 300',
#  'EcoSpold01Allocation_undefined_152',
#  'oriented strand board content',
#  'mass concentration, chromium',
#  'concentration, lead',
#  'processing_efficiency',
#  'cadmium content',
#  'EcoSpold01Allocation_undefined_103',
#  'EcoSpold01Allocation_other_118',
#  'nitrogen oxides emissions tier T2 for hp < 600',
#  'aluminium hydroxide content',
#  'EcoSpold01Allocation_physical_10',
#  'terbium content',
#  'EcoSpold01Allocation_undefined_167',
#  'amount from Québec dataset in kg',
#  'EcoSpold01Allocation_undefined_41',
#  'Corresponding fuel use, transport, freight train',
#  'EcoSpold01Allocation_physical_5',
#  'carbon monoxide emissions tier T1-T2-T4 for hp >= 750',
#  'ratio pf particulates greater than 10 microns',
#  'amount of exchange 4',
#  'suspended soilds, mass per volume',
#  'Erosivity factor',
#  'EcoSpold01Allocation_other_76',
#  'EcoSpold01Allocation_other_138',
#  'amount in multioutput activity_kBq',
#  'EcoSpold01Allocation_physical_6',
#  'thorium content',
#  'EcoSpold01Allocation_undefined_13',
#  'dry mass',
#  'amount of refractory material sent to recycling',
#  'EcoSpold01Allocation_undefined_1',
#  'EcoSpold01Allocation_other_81',
#  'EcoSpold01Allocation_other_59',
#  'amount in multioutput activity_kg',
#  'gallium content',
#  'EcoSpold01Allocation_undefined_16',
#  'hydrogen content',
#  'length, external',
#  'input_kWh_silver',
#  'EcoSpold01Allocation_undefined_126',
#  'EcoSpold01Allocation_undefined_11',
#  'polycyclic aromatic hydrocarbon content, total',
#  'nitrogen oxides emissions tier T2 for hp < 100',
#  'Tillage factor',
#  'mass concentration, calcium',
#  'percentage of associated gas',
#  'filter dust to landfill',
#  'EcoSpold01Allocation_undefined_170',
#  'EcoSpold01Allocation_other_57',
#  'SAM_activityLink_3_scaling_factor',
#  'mass concentration, tungsten',
#  'corresponding fuel use, propane, furnace >100kW',
#  'rhodium content',
#  'fuel input in physical units, L',
#  'amount of exchange in kg 2',
#  'chromium content',
#  'lifetime capacity [unit]',
#  'EcoSpold01Allocation_other_80',
#  'EcoSpold01Allocation_undefined_23',
#  'maximum payload',
#  'SAM_activityLink_10',
#  'EcoSpold01Allocation_other_82',
#  'SAM_activityLink_1_scaling_factor',
#  'EcoSpold01Allocation_undefined_57',
#  'EcoSpold01Allocation_undefined_160',
#  'EcoSpold01Allocation_undefined_164',
#  'mass concentration, ytterbium',
#  'amount of flow 3 in kg',
#  'mass concentration, beryllium',
#  'EcoSpold01Allocation_undefined_60',
#  'mass concentration, rhenium',
#  'EcoSpold01Allocation_other_9',
#  'mass concentration, mercury',
#  'cobalt content',
#  'EcoSpold01Allocation_undefined_78',
#  'mass concentration, thulium',
#  'concentration, nickel',
#  'EcoSpold01Allocation_physical_16',
#  'EcoSpold01Allocation_undefined_122',
#  'multiplicative factor',
#  'weight',
#  'EcoSpold01Allocation_undefined_137',
#  'EcoSpold01Allocation_undefined_80',
#  'EcoSpold01Allocation_undefined_150',
#  'EcoSpold01Allocation_undefined_59',
#  'EcoSpold01Allocation_other_42',
#  'nitrogen oxides emissions tier T0-T1 for hp < 11',
#  'EcoSpold01Allocation_other_126',
#  'EcoSpold01Allocation_other_50',
#  'mass concentration, holmium',
#  'fraction > 10microns',
#  'carbon monoxide emissions tier T2-T4A-T4B for hp < 25',
#  'EcoSpold01Allocation_undefined_14',
#  'molybdenum content',
#  'EcoSpold01Allocation_other_40',
#  'EcoSpold01Allocation_other_111',
#  'EcoSpold01Allocation_other_37',
#  'EcoSpold01Allocation_undefined_119',
#  'capacity [kg/s]',
#  'EcoSpold01Allocation_other_5',
#  'EcoSpold01Allocation_undefined_70',
#  'input_kg',
#  'EcoSpold01Allocation_other_116',
#  'carbon monoxide emissions tier T4N for hp >= 750',
#  'EcoSpold01Allocation_other_133',
#  'EcoSpold01Allocation_other_89',
#  'mass concentration, ruthenium',
#  'mass concentration, carbone dioxide',
#  'EcoSpold01Allocation_other_70',
#  'carbon monoxide emissions tier T1-T2-T4A for hp < 50',
#  'EcoSpold01Allocation_undefined_140',
#  'seeds per hectare',
#  'carbon monoxide emissions tier T4-T4N for hp < 175',
#  'erbium content',
#  'mass concentration, germanium',
#  'EcoSpold01Allocation_undefined_113',
#  'lifetime capacity',
#  'lifetime capacity [kg*day]',
#  'sodium hydroxide-to-hydroxide mass ratio',
#  'mass concentration, barium',
#  'EcoSpold01Allocation_undefined_166',
#  'density loose',
#  'xenon content',
#  'EcoSpold01Allocation_undefined_37',
#  'distance',
#  'EcoSpold01Allocation_undefined_111',
#  'EcoSpold01Allocation_undefined_24',
#  'amount of flow 2 in kg',
#  'SAM_activityLink_10_scaling_factor',
#  'EcoSpold01Allocation_undefined_46',
#  'EcoSpold01Allocation_undefined_134',
#  'mass concentration. lutetium',
#  'weight with a refrigeration unit',
#  'water in wet mass',
#  'EcoSpold01Allocation_other_3',
#  'EcoSpold01Allocation_other_60',
#  'nitrogen oxides emissions tier T1-T2 for hp < 50',
#  'sulfur content',
#  'concentration, chromium',
#  'EcoSpold01Allocation_other_20',
#  'carbon monoxide emissions tier T1-T2 for hp < 11',
#  'no. of deformation strokes',
#  'EcoSpold01Allocation_undefined_102',
#  'EcoSpold01Allocation_undefined_40',
#  'amount 3 of flow in kg',
#  'density argon',
#  'EcoSpold01Allocation_undefined_142',
#  'EcoSpold01Allocation_undefined_50',
#  'amount of exchange in kg 3',
#  'EcoSpold01Allocation_other_98',
#  'MARKET_OVERWRITE_AMOUNT_CONSEQUENTIAL',
#  'EcoSpold01Allocation_undefined_135',
#  'amount of exchange in liters 4',
#  'calculation property, unit',
#  'mass concentration, iodine',
#  'butanol input, volume',
#  'EcoSpold01Allocation_undefined_141',
#  'EcoSpold01Allocation_undefined_114',
#  'nitrogen oxides emissions tier T2-T4-T4A for hp < 75',
#  'aluminium content',
#  'carbon monoxide emissions tier T4-T4N for hp < 100',
#  'conversion factor m3 to MJ',
#  'EcoSpold01Allocation_other_65',
#  'mercury content',
#  'external scrap',
#  'carbon monoxide emissions tier T1-T2-T3B for hp < 100',
#  'EcoSpold01Allocation_other_55',
#  'mass concentration, radium',
#  'EcoSpold01Allocation_undefined_51',
#  'mass concentration, hafnium',
#  'EcoSpold01Allocation_undefined_151',
#  'amount from Québec dataset in m³',
#  'tantalum content',
#  'EcoSpold01Allocation_other_91',
#  'barium content',
#  'EcoSpold01Allocation_undefined_15',
#  'EcoSpold01Allocation_undefined_56',
#  'corresponding fuel use, in m3',
#  'recovery rate',
#  'EcoSpold01Allocation_other_135',
#  'fraction, origin: fresh water',
#  'polonium content',
#  'boiling point',
#  'phosphorus content',
#  'carbon monoxide emissions tier T0-T1 for hp >= 100',
#  'EcoSpold01Allocation_other_100',
#  'iridium content',
#  'price',
#  'EcoSpold01Allocation_other_137',
#  'carbon monoxide emissions tier T0-T1 for hp < 100',
#  'annual production',
#  'input_kWh_gold',
#  'EcoSpold01Allocation_undefined_7',
#  'carbon monoxide emissions tier T1-T2 for hp < 100',
#  'EcoSpold01Allocation_other_10',
#  'EcoSpold01Allocation_other_53',
#  'amount in multioutput activity_unit',
#  'nitrogen oxides emissions tier T2-T4-T4A for hp < 50',
#  'EcoSpold01Allocation_other_103',
#  'actinium content',
#  'mass concentration, tin',
#  'helium content',
#  'EcoSpold01Allocation_other_29',
#  'Quebec production volume in m³',
#  'oil content',
#  'recycled spent pot liner carbon',
#  'carbon monoxide emissions tier T2-T3 for hp < 600',
#  'EcoSpold01Allocation_physical_13',
#  'selenium content',
#  'oil/fat content',
#  'fossil share of carbon',
#  'SAM_activityLink_5',
#  'total length of network',
#  'EcoSpold01Allocation_other_75',
#  'EcoSpold01Allocation_undefined_85',
#  'EcoSpold01Allocation_other_26',
#  'UVEK_absolute_amount_3',
#  'EcoSpold01Allocation_other_48',
#  'thulium content',
#  'EcoSpold01Allocation_undefined_92',
#  'bulk density',
#  'EcoSpold01Allocation_undefined_146',
#  'lifetime capacity in m3',
#  'pH',
#  'carbon monoxide emissions tier T4 for hp < 50',
#  'rubidium content',
#  'nitrogen oxides emissions tier T1 for hp < 750',
#  'heating value, net',
#  'EcoSpold01Allocation_undefined_29',
#  'mass concentration, strontium',
#  'Surface',
#  'EcoSpold01Allocation_undefined_39',
#  'nitrogen oxides emissions tier T1 for hp < 11',
#  'scandium content',
#  'capacity factor',
#  'concentration, iron',
#  'lumber content',
#  'EcoSpold01Allocation_undefined_19',
#  'plant average daily flow rate',
#  'EcoSpold01Allocation_other_62',
#  'EcoSpold01Allocation_other_119',
#  'SAM_activityLink_3',
#  'chemical factory annual production',
#  'zirconium content',
#  'hydraulic oil input',
#  'EcoSpold01Allocation_physical_3',
#  'EcoSpold01Allocation_other_1',
#  'phenol resorcinol formaldehyde resin content',
#  'volume',
#  'tin content',
#  'capacity [kg]',
#  'mass concentration, chlorine',
#  'mass concentration, cobalt',
#  'samarium content',
#  'EcoSpold01Allocation_other_129',
#  'EcoSpold01Allocation_physical_15',
#  'EcoSpold01Allocation_other_31',
#  'EcoSpold01Allocation_other_112',
#  'EcoSpold01Allocation_other_6',
#  'EcoSpold01Allocation_other_13',
#  'mass concentration. lanthanum',
#  'lifetime capacity [MJ]',
#  'nitrogen oxides emissions tier T4A for hp < 50',
#  'EcoSpold01Allocation_other_125',
#  'price CHF',
#  'mass concentration, antimony',
#  'mass concentration, silver',
#  'mass concentration, praseodymium',
#  'mass concentration, cerium',
#  'EcoSpold01Allocation_other_109',
#  'mass concentration, particulate nitrogen',
#  'EcoSpold01Allocation_other_49',
#  'mass concentration, selenium',
#  'EcoSpold01Allocation_undefined_174',
#  'fraction of diesel sulfur converted to direct PM (hydrated sulfuric acid)',
#  'EcoSpold01Allocation_other_71',
#  'carbon monoxide emissions tier T4A for hp < 75',
#  'EcoSpold01Allocation_other_108',
#  'EcoSpold01Allocation_undefined_172',
#  'lifetime capacity [kWh]',
#  'carbon monoxide emissions tier T4A-T4B for hp < 25',
#  'amount 5 of flow in kg',
#  'mass concentration, hydrogen',
#  'heating value, net, natural gas',
#  'consumption ratio',
#  'EcoSpold01Allocation_undefined_173',
#  'mass concentration, samarium',
#  'francium content',
#  'length, internal',
#  'EcoSpold01Allocation_undefined_107',
#  'sand content',
#  'Corresponding fuel use',
#  'EcoSpold01Allocation_undefined_159',
#  'EcoSpold01Allocation_undefined_63',
#  'EcoSpold01Allocation_undefined_3',
#  'value per kg of bi-metal cable',
#  'EcoSpold01Allocation_undefined_132',
#  'EcoSpold01Allocation_undefined_34',
#  'EcoSpold01Allocation_undefined_65',
#  'sodium content',
#  'bromine content',
#  'europium content',
#  'EcoSpold01Allocation_undefined_2',
#  'nitrogen oxides emissions tier T4N for hp >= 750',
#  'bark',
#  'EcoSpold01Allocation_undefined_43',
#  'EcoSpold01Allocation_undefined_12',
#  'mass concentration, terbium',
#  'EcoSpold01Allocation_undefined_31',
#  'EcoSpold01Allocation_undefined_38',
#  'mass concentration, neon',
#  'EcoSpold01Allocation_other_93',
#  'mass concentration, gold',
#  'carbohydrates content',
#  'EcoSpold01Allocation_undefined_100',
#  'nitrogen oxides emissions tier T3B for hp < 100',
#  'EcoSpold01Allocation_undefined_17',
#  'protactinium content',
#  'EcoSpold01Allocation_other_23',
#  'SAM_activityLink_6_scaling_factor',
#  'production in l',
#  'EcoSpold01Allocation_undefined_104',
#  'carbon monoxide emissions tier T2-T3-T4-T4N for hp < 300',
#  'EcoSpold01Allocation_undefined_75',
#  'mass concentration, protactinium',
#  'paint volatile content',
#  'fuel consumption tier T0-T1-T2-T4A-T4B for hp < 25',
#  'mass concentration, phophorus',
#  'EcoSpold01Allocation_undefined_36',
#  'amount from Québec dataset in MJ',
#  'EcoSpold01Allocation_undefined_106',
#  'EcoSpold01Allocation_undefined_79',
#  'calcium content',
#  'SAM_activityLink_6',
#  'P to surface water',
#  'EcoSpold01Allocation_undefined_71',
#  'EcoSpold01Allocation_physical_8',
#  'carbon monoxide emissions tier T1-T2-T4A-T4B for hp <25',
#  'mass concentration, DOC',
#  'uranium content',
#  'wet mass',
#  'EcoSpold01Allocation_undefined_30',
#  'consumption in litre',
#  'ratio of particulates between 2.5 and 10 microns',
#  'oxygen content',
#  'carbon monoxide emissions tier T2-T3-T4-T4N for hp < 175',
#  'mass of fuel used',
#  'nitrogen oxides emissions tier T4N for hp < 750',
#  'EcoSpold01Allocation_undefined_99',
#  'mass concentration, chloride',
#  'nitrogen oxides emissions tier T2-T3-T4-T4N for hp < 175',
#  'capacity, cargo',
#  'concentration, cadmium',
#  'amount of exchange in liters 3',
#  'amount of exchange in liters 1',
#  'EcoSpold01Allocation_other_15',
#  'EcoSpold01Allocation_other_38',
#  'fuel input in physical units, kg',
#  'batch water',
#  'mass concentration, manganese',
#  'EcoSpold01Allocation_undefined_88',
#  'input',
#  'EcoSpold01Allocation_physical_4',
#  'chromium, fraction',
#  'carbon monoxide emissions tier T4-T4N for hp < 750',
#  'nitrogen oxides emissions tier T4 for hp < 750',
#  'mass concentration, oxygen',
#  'EcoSpold01Allocation_undefined_84',
#  'EcoSpold01Allocation_undefined_87',
#  'EcoSpold01Allocation_undefined_144',
#  'true value relation',
#  'carbon monoxide emissions tier T1-T2 for hp < 50',
#  'nickel content',
#  'EcoSpold01Allocation_undefined_61',
#  'mass concentration, zinc',
#  'iron content',
#  'protein content',
#  'carbon monoxide emissions tier T1-T2-T3B-T4A for hp <100',
#  'ratio of total particulates less than 2.5 microns',
#  'dysprosium content',
#  'mass concentration, bicarbonate',
#  'amount in multioutput activity_m',
#  'EcoSpold01Allocation_other_18',
#  'carbon monoxide emissions tier T2-T3-T4-T4N for hp < 600',
#  'polyurethane content',
#  'EcoSpold01Allocation_undefined_26',
#  'EcoSpold01Allocation_other_45',
#  'concentration of amount 2',
#  'nitrogen oxides emissions tier T2 for hp < 11',
#  'mass concentration, vanadium',
#  'width, internal',
#  'EcoSpold01Allocation_other_90',
#  'fuel input in physical units m3',
#  'nitrogen oxides emissions tier T0 for hp < 11',
#  'nitrogen oxides emissions tier T2-T3-T4-T4N for hp < 600',
#  'EcoSpold01Allocation_undefined_10',
#  'nitrogen oxides emissions tier T0 for hp >= 100',
#  'strontium content',
#  'concentration, copper',
#  'dinitrogen monoxide factor',
#  'carbon monoxide emissions tier T0 for hp < 25',
#  'UVEK_link_3',
#  'EcoSpold01Allocation_undefined_8',
#  'COD, mass per volume',
#  'EcoSpold01Allocation_other_28',
#  'gross energy, feed per kg of dry mass',
#  'EcoSpold01Allocation_undefined_116',
#  'EcoSpold01Allocation_undefined_157',
#  'EcoSpold01Allocation_undefined_55',
#  'mass concentration, erbium',
#  'mass concentration, carbonate',
#  'EcoSpold01Allocation_undefined_98',
#  'calculation property, nacelle, kg',
#  'mass concentration, carbonic acid',
#  'concentration',
#  'mass concentration, palladium',
#  'concentration, zinc',
#  'amount from semichemical fluting production in kg',
#  'mass concentration, potassium',
#  'amount 2 of flow in kg',
#  'used oil fraction emitted to soil',
#  'mass concentration, molybdenum',
#  'fluoranthene content',
#  'carbon monoxide emissions tier T1-T2-T4A-T4B for hp < 11',
#  'EcoSpold01Allocation_other_35',
#  'EcoSpold01Allocation_undefined_133',
#  'tungsten content',
#  'EcoSpold01Allocation_undefined_66',
#  'EcoSpold01Allocation_undefined_5',
#  'nitrogen oxides emissions tier T2-T4A-T4B for hp < 25',
#  'EcoSpold01Allocation_other_56',
#  'organic carbon content',
#  'carbon monoxide emissions tier T2-T3B-T4-T4A-T4N for hp < 100',
#  'kgFuel_Input',
#  'UVEK_link_2',
#  'mass concentration, dissolved sulfate SO4 as S',
#  'EcoSpold01Allocation_other_132',
#  'mass concentration, dissolved nitrate NO3 as N',
#  'EcoSpold01Allocation_undefined_161',
#  'carbon monoxide emissions tier T2-T4-T4N for hp >= 750',
#  'lanthanum content',
#  'Slope Factor',
#  'nitrogen oxides emissions tier T2-T3-T4-T4N for hp >= 600',
#  'filter dust to recycling',
#  'low calorific value',
#  'EcoSpold01Allocation_physical_14',
#  'EcoSpold01Allocation_other_24',
#  'arsenic content',
#  'SAM_activityLink_2',
#  'width, external',
#  'EcoSpold01Allocation_undefined_118',
#  'mass concentration, cadmium',
#  'EcoSpold01Allocation_undefined_93',
#  'EcoSpold01Allocation_undefined_117',
#  'EcoSpold01Allocation_undefined_25',
#  'regional dataset numerical value',
#  'EcoSpold01Allocation_other_113',
#  'EcoSpold01Allocation_other_128',
#  'EcoSpold01Allocation_undefined_115',
#  'EcoSpold01Allocation_other_44',
#  'carbon monoxide emissions tier T1 for hp < 600',
#  'amount of exchange in MJ 1',
#  'carbon monoxide emissions tier T4-T4N for hp < 600',
#  'nitrogen oxides emissions tier T0 for hp < 100',
#  'global dataset numerical value',
#  'EcoSpold01Allocation_undefined_54',
#  'mass concentration, caesium',
#  'total polycyclic aromatic hydrocarbon content',
#  'EcoSpold01Allocation_undefined_97',
#  'EcoSpold01Allocation_other_92',
#  'fibre (total dietary) content',
#  'working time',
#  'praseodymium content',
#  'EcoSpold01Allocation_other_46',
#  'heating value, gross',
#  'mass concentration, arsenic',
#  'yearly output',
#  'EcoSpold01Allocation_undefined_138',
#  'EcoSpold01Allocation_undefined_64',
#  'mass concentration, gallium',
#  'fraction between 2.5 and 10 microns',
#  'nitrogen oxides emissions tier T1 for hp >= 750',
#  'mass concentration, rhodium',
#  'mass concentration, copper',
#  'manganese content',
#  'nitrogen oxides emissions tier T0 for hp < 25',
#  'carbon monoxide emissions tier T0 for hp < 50',
#  'SAM_activityLink_9_scaling_factor',
#  'amount 7 of flow in kg',
#  'EcoSpold01Allocation_other_22',
#  'UVEK_absolute_amount_2',
#  'amount of flow 1 in kg',
#  'SAM_activityLink_8',
#  'mass concentration, argon',
#  'lutetium content',
#  'EcoSpold01Allocation_undefined_9',
#  'vanadium content',
#  'amount in multioutput activity_km',
#  'amount of exchange 1',
#  'Erodibility factor',
#  'EcoSpold01Allocation_other_2',
#  'mass concentration, gadolinium',
#  'EcoSpold01Allocation_physical_9',
#  'carbon monoxide emissions tier T2-T4-T4A for hp < 50',
#  'SAM_activityLink_7_scaling_factor',
#  'fraction, origin: salt water',
#  'EcoSpold01Allocation_physical_7',
#  'EcoSpold01Allocation_undefined_139',
#  'nitrogen oxides emissions tier T1-T2 for hp < 25',
#  'EcoSpold01Allocation_other_27',
#  'water content',
#  'copper content',
#  'EcoSpold01Allocation_other_99',
#  'mass concentration, platinum',
#  'EcoSpold01Allocation_undefined_52',
#  'chromium layer thickness',
#  'EcoSpold01Allocation_other_131',
#  'concentration of amount 4',
#  'nitrogen oxides emissions tier T0-T1 for hp >= 100',
#  'EcoSpold01Allocation_undefined_90',
#  'fuel consumption tier T0-T1-T2-T3-T4-T4N for hp >= 100',
#  'EcoSpold01Allocation_undefined_147',
#  'EcoSpold01Allocation_undefined_171',
#  'corresponding fuel use, natural gas',
#  'EcoSpold01Allocation_undefined_42',
#  'active membrane surface per module unit',
#  'EcoSpold01Allocation_other_47',
#  'carbon content, fossil',
#  'EcoSpold01Allocation_undefined_123',
#  'mass concentration, tantalum',
#  'MARKET_OVERWRITE_PV_CUTOFF',
#  'capacity',
#  'carbon monoxide emissions tier T2-T3-T4-T4N for hp < 750',
#  'EcoSpold01Allocation_other_84',
#  'EcoSpold01Allocation_undefined_44',
#  'carbon monoxide emissions tier T2-T4A-T4B for hp < 11',
#  'EcoSpold01Allocation_undefined_6',
#  'value per m of bi-metal cable',
#  'mass of a straw bale',
#  'EcoSpold01Allocation_undefined_96',
#  'MARKET_OVERWRITE_PV_APOS',
#  'consequential',
#  'concentration of solution',
#  'BOD5, mass per volume',
#  'EcoSpold01Allocation_other_34',
#  'germanium content',
#  'EcoSpold01Allocation_undefined_165',
#  'mass concentration, niobium',
#  'EcoSpold01Allocation_undefined_156',
#  'EcoSpold01Allocation_other_114',
#  'transport distance',
#  'concentration of amount 6',
#  'conversion factor kg to MJ',
#  'lifetime capacity [h]',
#  'exergy',
#  'EcoSpold01Allocation_undefined_20',
#  'fuel consumption tier T0-T1-T2-T3B-T4-T4A-T4N for hp < 100',
#  'carbon content',
#  'methane factor',
#  'silicon content',
#  'total surface',
#  'Quebec production volume',
#  'humus equivalent',
#  'EcoSpold01Allocation_other_83',
#  'chromium layer reference thickness',
#  'EcoSpold01Allocation_undefined_22',
#  'fuel input in physical units, m3, natural gas',
#  'EcoSpold01Allocation_other_97',
#  'EcoSpold01Allocation_undefined_143',
#  'tcdd equivalents',
#  'EcoSpold01Allocation_other_66',
#  'EcoSpold01Allocation_other_121',
#  'mass per seed',
#  'mass concentration, europium',
#  'EcoSpold01Allocation_other_110',
#  'EcoSpold01Allocation_other_104',
#  'mass concentration, yttrium',
#  'volume of fuel used',
#  'length',
#  'mass concentration, bromine',
#  'energy content',
#  'UVEK_absolute_amount2',
#  'EcoSpold01Allocation_other_68',
#  'EcoSpold01Allocation_undefined_53',
#  'mass concentration, francium',
#  'N content',
#  'EcoSpold01Allocation_other_54',
#  'amount of refractory material sent to landfill',
#  'mass concentration, thorium',
#  'mass concentration, TOC',
#  'occupation period',
#  'mass concentration, indium',
#  'mass concentration, rubidium',
#  'EcoSpold01Allocation_undefined_86',
#  'EcoSpold01Allocation_other_120',
#  'lower heating value MJ per kg',
#  'lifetime capacity [l]',
#  'nitrogen oxides emissions tier T0-T1 for hp < 100',
#  'potassium content',
#  'nitrogen oxides emissions tier T1-T2-T4A for hp <50',
#  'EcoSpold01Allocation_other_136',
#  'mass concentration, boron',
#  'nitrogen oxides emissions tier T4-T4A for hp < 100',
#  'EcoSpold01Allocation_other_25',
#  'carbon monoxide emissions tier T1-T2 for hp < 25',
#  'nitrogen oxides emissions tier T4-T4N for hp >= 750',
#  'gravel content',
#  'mass concentration, dysprosium',
#  'EcoSpold01Allocation_undefined_27',
#  'EcoSpold01Allocation_undefined_82',
#  'net heating value, per m3',
#  'cerium content',
#  'total PAH emission to air',
#  'antimony content',
#  'mass concentration, bismuth',
#  'EcoSpold01Allocation_physical_17',
#  'beryllium content',
#  'nitrogen oxides emissions tier T4N for hp < 100',
#  'mass concentration, neodymium',
#  'molecular weight',
#  'percentage of non associated gas',
#  'EcoSpold01Allocation_other_30',
#  'EcoSpold01Allocation_other_63',
#  'capacity [l/hour]',
#  'EcoSpold01Allocation_other_67',
#  'thermal efficiency',
#  'EcoSpold01Allocation_undefined_83',
#  'dross sent to recycling',
#  'concentration of amount 1',
#  'mass concentration, particulate sulfur',
#  'rhenium content',
#  'nitrogen oxides emissions tier T0-T1 for hp < 25',
#  'total particulates > 2.5microns',
#  'input_kg_recycled',
#  'mass concentration, sodium',
#  'UVEK_relative_amount_1',
#  'total particulates',
#  'weight per length',
#  'ytterbium content',
#  'amount in mass units',
#  'EcoSpold01Allocation_other_8',
#  'mass concentration, dissolved phosphate PO4 as P',
#  'mass concentration, nitrogen',
#  'EcoSpold01Allocation_undefined_101',
#  'yttrium content',
#  'nitrogen oxides emissions tier T1 for hp < 175',
#  'clay content',
#  'EcoSpold01Allocation_other_77',
#  'lifetime capacity [kg]',
#  'EcoSpold01Allocation_undefined_121',
#  'concentration, nitrogen',
#  'calculation property, blade, kg',
#  'EcoSpold01Allocation_other_123',
#  'SAM_activityLink_7',
#  'EcoSpold01Allocation_undefined_35',
#  'Organic Nitrogen content of soil',
#  'amount of exchange 6',
#  'nitrogen oxides emissions tier T1-T2-T4A-T4B for hp < 25',
#  'EcoSpold01Allocation_undefined_67',
#  'solution concentration',
#  'SAM_activityLink_4_scaling_factor',
#  'amount of exchange in m³ 1',
#  'EcoSpold01Allocation_undefined_76',
#  'fat content',
#  'kgFuel_input_in_process',
#  'mass concentration, uranium',
#  'EcoSpold01Allocation_other_12',
#  'lifetime capacity [metric ton*km]',
#  'height, internal',
#  'Practice factor',
#  'share of methane in biogas',
#  'calculation property, kg',
#  'argon content',
#  'EcoSpold01Allocation_other_21',
#  'mass concentration, lead',
#  'mass concentration, dissolved Kjeldahl Nitrogen as N',
#  'EcoSpold01Allocation_undefined_45',
#  'carbon monoxide emissions tier T4-T4N for hp < 300',
#  'MARKET_OVERWRITE_PV_CONSEQUENTIAL',
#  'holmium content',
#  'SAM_activityLink_4',
#  'amount 6 of flow in kg',
#  'EcoSpold01Allocation_other_17',
#  'carbon allocation',
#  'EcoSpold01Allocation_other_58',
#  'EcoSpold01Allocation_undefined_58',
#  'EcoSpold01Allocation_undefined_4',
#  'EcoSpold01Allocation_undefined_18',
#  'amount in multioutput activity_m3',
#  'EcoSpold01Allocation_undefined_120',
#  'carbon monoxide emissions tier T0-T1 for hp < 25',
#  'EcoSpold01Allocation_undefined_89',
#  'EcoSpold01Allocation_undefined_94',
#  'EcoSpold01Allocation_undefined_155',
#  'lead content',
#  'EcoSpold01Allocation_other_69',
#  'EcoSpold01Allocation_undefined_125',
#  'EcoSpold01Allocation_undefined_124',
#  'EcoSpold01Allocation_undefined_129',
#  'Slope',
#  'amount of exchange 2',
#  'carbon monoxide emissions tier T1-T2-T3 for hp < 750',
#  'tellurium content',
#  'amount in multioutput activity_kWh',
#  'silica dioxide',
#  'dry wood density',
#  'EcoSpold01Allocation_undefined_110',
#  'indium content',
#  'chlorine content',
#  'carbon monoxide emissions tier T1-T2-T3 for hp < 175',
#  'SAM_activityLink_2_scaling_factor',
#  'EcoSpold01Allocation_undefined_145',
#  'bismuth content',
#  'boron content',
#  'ammonium fraction of total nitrogen',
#  'EcoSpold01Allocation_other_134',
#  'neodymium content',
#  'EcoSpold01Allocation_undefined_47',
#  'EcoSpold01Allocation_undefined_131',
#  'EcoSpold01Allocation_undefined_127',
#  'concentration, calcium',
#  'mass concentration, dissolved organic nitrogen as N',
#  'nitrogen oxides emissions tier T3 for hp < 750',
#  'EcoSpold01Allocation_other_87',
#  'EcoSpold01Allocation_undefined_158',
#  'EcoSpold01Allocation_other_94',
#  'fluorine content',
#  'amount in multioutput activity_MJ',
#  'calculation property, kBq',
#  'nitrogen oxides emissions tier T3-T4 for hp < 750',
#  'astatine content',
#  'EcoSpold01Allocation_undefined_77',
#  'EcoSpold01Allocation_other_19',
#  'mass concentration, magnesium',
#  'nitrogen oxides emissions tier T2 for hp >= 600',
#  'EcoSpold01Allocation_other_4',
#  'concentration, mercury',
#  'fly ash content',
#  'm3Fuel_input',
#  'EcoSpold01Allocation_other_96',
#  'mass concentration, iron',
#  'carbon dioxide factor',
#  'osmium content',
#  'density',
#  'concentration, sulfur',
#  'concentration, phosphorus',
#  'laminated veneer lumber content',
#  'benzopyrene content',
#  'SAM_activityLink_1',
#  'EcoSpold01Allocation_undefined_81',
#  'EcoSpold01Allocation_other_39',
#  'true value',
#  'hafnium content',
#  'concentration, indium',
#  'mass concentration, dissolved ammonia NH4 as N',
#  'EcoSpold01Allocation_other_72',
#  'fibre content',
#  'SAM_activityLink_5_scaling_factor',
#  'EcoSpold01Allocation_undefined_168',
#  'mass concentration, fluoride',
#  'EcoSpold01Allocation_undefined_69',
#  'digestable energy content',
#  'EcoSpold01Allocation_undefined_162',
#  'amount of exchange 5',
#  'fraction, origin: unspecified',
#  'magnesium content',
#  'P to groundwater',
#  'amount of exchange in liters 5',
#  'net heating value',
#  'carbon monoxide emissions tier T4A-T4B for hp < 11',
#  'EcoSpold01Allocation_physical_2',
#  'EcoSpold01Allocation_other_95',
#  'emitted fraction',
#  'protein feed, 100% crude per kg of dry mass',
#  'caesium content',
#  'emission ratio',
#  'percentage of sour gas',
#  'EcoSpold01Allocation_other_41',
#  'EcoSpold01Allocation_other_61',
#  'mass concentration, iridium',
#  'cement content',
#  'EcoSpold01Allocation_undefined_149',
#  'EcoSpold01Allocation_other_107',
#  'iodine content',
#  'carbon monoxide emissions tier T1-T2-T3 for hp < 300',
#  'niobium content',
#  'carbon monoxide emissions tier T0 for hp >= 100',
#  'EcoSpold01Allocation_other_73',
#  'UVEK_relative_amount_2',
#  'mass concentration, helium',
#  'EcoSpold01Allocation_other_43',
#  'UVEK_relative_amount_3',
#  'primary aluminium',
#  'EcoSpold01Allocation_undefined_130',
#  'MARKET_OVERWRITE_AMOUNT_CUTOFF']

# %%
parser.ecospold_to_Leontief(fileformats=['Pandas', 'SparseMatrix'], with_absolute_flows=True, )
# Out:
# 2020-05-21 13:29:40,002 - ecoinvent_3-6_cutoff_symm - INFO - Products extracted from IntermediateExchanges.xml with SHA-1 of f462df6b314c131986d790d4503f806e46126845
# 2020-05-21 13:30:14,927 - ecoinvent_3-6_cutoff_symm - WARNING - Removed 1073 duplicate rows from activity_list, see duplicate_activity_list.csv.
# 2020-05-21 13:30:14,981 - ecoinvent_3-6_cutoff_symm - INFO - Activities extracted from ActivityIndex.xml with SHA-1 of 1026b1b395d62da475f6eea059907932ee542bc4
# 2020-05-21 13:30:15,082 - ecoinvent_3-6_cutoff_symm - INFO - Processing 18121 files in /mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_cut-off_ecoSpold02/datasets
# 2020-05-21 13:31:47,525 - ecoinvent_3-6_cutoff_symm - INFO - Flows saved in /mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_cut-off_ecoSpold02/flows.pickle with SHA-1 of 5fd4f8e230ae45ded280c4ec0d59f1e25ce5ac80
# 2020-05-21 13:31:47,625 - ecoinvent_3-6_cutoff_symm - INFO - Processing 18121 files - this may take a while ...
# 2020-05-21 13:33:11,152 - ecoinvent_3-6_cutoff_symm - INFO - Elementary flows extracted from ElementaryExchanges.xml with SHA-1 of 3abfcfbaacb3cc91011ea4721c4bbeaa154f45aa
# 2020-05-21 13:33:11,290 - ecoinvent_3-6_cutoff_symm - INFO - Labels saved in /mnt/collection/data/ecoinvent/3.6/raw_data/ecoinvent_3.6_cut-off_ecoSpold02/rawlabels.pickle with SHA-1 of b360a80a95234c247a1d3813af3df2a3cb564daf
# 2020-05-21 13:33:11,306 - ecoinvent_3-6_cutoff_symm - INFO - OK.   No untraceable flows.
# 2020-05-21 13:33:11,599 - ecoinvent_3-6_cutoff_symm - INFO - OK. Source activities seem in order. Each product traceable to an activity that actually does produce or distribute this product.
# 2020-05-21 13:33:12,152 - ecoinvent_3-6_cutoff_symm - INFO - Starting to assemble the matrices
# 2020-05-21 13:33:16,454 - ecoinvent_3-6_cutoff_symm - INFO - fillna
# 2020-05-21 13:33:35,483 - ecoinvent_3-6_cutoff_symm - INFO - Starting normalizing matrices
# 2020-05-21 13:34:07,362 - ecoinvent_3-6_cutoff_symm - INFO - Characterisation file seems to be ecoinvent LCIA implementation. Will apply simple name matching
# starting characterisation
# 2020-05-21 13:34:44,353 - ecoinvent_3-6_cutoff_symm - INFO - Will use column 7, named CF_36, for characterisation factors
# 2020-05-21 13:34:44,354 - ecoinvent_3-6_cutoff_symm - INFO - Starting characterisation matching
# 2020-05-21 13:34:53,018 - ecoinvent_3-6_cutoff_symm - INFO - Characterisation matching done. C matrix created
# 2020-05-21 13:34:53,075 - ecoinvent_3-6_cutoff_symm - INFO - Starting to export to file
# 2020-05-21 13:34:53,075 - ecoinvent_3-6_cutoff_symm - INFO - about to write to file
# 2020-05-21 13:34:58,897 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, normalized matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmPandas_symmNorm.gz.pickle with SHA-1 of fab62b5469a1958f7076e388573796db48b88a73
# 2020-05-21 13:35:04,169 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, scaled-up flow matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmPandas_symmScale.gz.pickle with SHA-1 of 22ac4e0d1ecd6c1d410e9fa4f0a021df75abeebc
# 2020-05-21 13:35:06,350 - ecoinvent_3-6_cutoff_symm - INFO - about to write to file
# 2020-05-21 13:35:07,472 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, normalized matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmSparseMatrix_symmNorm.gz.pickle with SHA-1 of 37453840604243447ab7f922a30a15732d707606
# 2020-05-21 13:35:29,813 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, normalized matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmSparseMatrix_symmNorm.mat with SHA-1 of 9e30d07e1f2e154403516d3cdfd53720d401650f
# 2020-05-21 13:35:32,665 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, scaled-up flow matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmSparseMatrix_symmScale.gz.pickle with SHA-1 of eedb37dee171379a22690f73e8e122701d3916b4
# 2020-05-21 13:35:55,457 - ecoinvent_3-6_cutoff_symm - INFO - Final, symmetric, scaled-up flow matrices saved in /mnt/collection/data/ecoinvent/3.6/ecoinvent_3-6_cutoff_symmSparseMatrix_symmScale.mat with SHA-1 of d8ea8182f0d14d8f7fbc4af5fc681343a42d2eb8
# 2020-05-21 13:35:55,466 - ecoinvent_3-6_cutoff_symm - INFO - Done running ecospold2matrix.ecospold_to_Leontief

# %%
# We can access key variables directly from the parser
parser.PRO.iloc[256]
# Out:
# activityId                                   8a3d1a66-89fc-479f-857e-3852175bf0ee
# productId                                    98813ba1-c1a0-469d-99e0-6f2d8453c47d
# activityName                         bell pepper production, in heated greenhouse
# ISIC                            0113:Growing of vegetables and melons, roots a...
# price                                                                    0.687623
# priceUnit                                                                 EUR2005
# EcoSpoldCategory                                                              NaN
# geography                                                                     GLO
# technologyLevel                                                           Current
# macroEconomicScenario                                           Business-as-Usual
# productionVolume                                                      3.44975e+10
# productName                                                           bell pepper
# unitName                                                                       kg
# cpc                             01231: Chillies and peppers, green (Capsicum s...
# wet mass [kg]                                                                   1
# dry mass [kg]                                                               0.071
# iron content [dimensionless]                                                  NaN
# activityNameId                               2de85e14-cf0f-4799-9590-15ecc7d11313
# activityType                                                                    0
# startDate                                                              2010-01-01
# endDate                                                                2019-12-31
# Name: 8a3d1a66-89fc-479f-857e-3852175bf0ee_98813ba1-c1a0-469d-99e0-6f2d8453c47d, dtype: object

# %%
# Let us delete the parser (free the RAM) and load the system file we just produced
del(parser)

# %%
with gzip.open('ecoinvent_3-6_cutoff_symmPandas_symmNorm.gz.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['PRO', 'STR', 'IMP', 'A', 'F', 'C', 'PRO_header', 'STR_header', 'IMP_header', 'processingdata'])

# %%
data['A']
# Out:
# index                                               c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3f9c-4074-bd34-eba76a61760c  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3f9c-4074-bd34-eba76a61760c  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c05d-410a-a784-06e3508e78e6  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1a25-41b4-a821-81f5726d86e5  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1a25-41b4-a821-81f5726d86e5  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               fad1fdbf-677f-48f3-8ad3-58e4834dec9a_3f6dada9-2497-4e1c-9e1b-eabafa6920f8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               d8ffe66f-0406-42ab-a327-33d510452291_3f6dada9-2497-4e1c-9e1b-eabafa6920f8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               f0cca009-1b74-400d-a011-cd10f2239468_3f6dada9-2497-4e1c-9e1b-eabafa6920f8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               69964911-3ae6-4dad-b1c2-238a9c360cc0_3f6dada9-2497-4e1c-9e1b-eabafa6920f8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               c8ab41c1-0274-45a1-883f-09b19d8d5991_3f6dada9-2497-4e1c-9e1b-eabafa6920f8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               ...  \
# index                                               ...
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...  ...
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...  ...
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...  ...
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...  ...
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...  ...
# ...                                                 ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...  ...
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...  ...
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...  ...
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...  ...
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...  ...
#
# index                                               be9a71fe-fb3d-4aad-8f42-226042b9b89d_fd27af60-7b68-4549-bf35-022eacd74f93  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               9fdd1edb-b742-4cc4-9c1b-21997ad46b61_ad38bbd2-e41c-4509-9dc3-c5c708a36606  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               b4c75eda-be8b-4797-80e3-d4ae473a4390_2cb0d6c6-349c-46fc-b31f-a036c847a267  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               cedddfe5-3a4e-496c-80d7-7671e44d2c1e_ce165995-6d94-44a8-ac3b-d5860c2c7fdb  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               c7e32113-5fef-428e-bff1-dd620c55772f_b3184435-d00c-5713-823d-5ff6741bfbbc  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7d6a-55d2-8380-86343a80fed8  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c6c8-56a7-a518-b01dd3e8a453  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2da0-528b-96fd-21687e242c1c  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d9e6-4396-9f9a-97e752111228  \
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# index                                               fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-fa54-45d5-85c6-5e3f5b89b20e
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3...                                                0.0
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3...                                                0.0
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c...                                                0.0
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1...                                                0.0
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1...                                                0.0
# ...                                                                                               ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7...                                                0.0
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c...                                                0.0
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2...                                                0.0
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d...                                                0.0
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-f...                                                0.0
#
# [18121 rows x 18121 columns]

# %%
# the A-matrix follows the new SparseDtype format
data['A'].dtypes
# Out:
# index
# c8b440f1-9fc2-4ca8-9be9-557f35379138_aeaf5266-3f9c-4074-bd34-eba76a61760c    Sparse[float64, 0.0]
# 4e3ebe0d-fbf1-4f6f-864b-6751b69c9757_aeaf5266-3f9c-4074-bd34-eba76a61760c    Sparse[float64, 0.0]
# c2d31fc1-1199-43b7-89b5-166f451af9b5_281fc4f0-c05d-410a-a784-06e3508e78e6    Sparse[float64, 0.0]
# c5897e33-3ed2-445a-9f68-7274dbb508df_0d860eb4-1a25-41b4-a821-81f5726d86e5    Sparse[float64, 0.0]
# 7248ba47-11dd-47e5-b5c6-02b942bc3f16_0d860eb4-1a25-41b4-a821-81f5726d86e5    Sparse[float64, 0.0]
#                                                                                      ...
# e705fefd-3afb-4889-a59f-ddfeb6b5779e_d13ae29b-7d6a-55d2-8380-86343a80fed8    Sparse[float64, 0.0]
# 8905d83f-7d46-4f0f-88bf-0aa7a8e9ea83_ed25f589-c6c8-56a7-a518-b01dd3e8a453    Sparse[float64, 0.0]
# e4964245-a8dc-4daa-bcd0-5e73099bab33_101e55f2-2da0-528b-96fd-21687e242c1c    Sparse[float64, 0.0]
# 1d009030-88b9-4784-be04-ed520ad97f0b_451550a8-d9e6-4396-9f9a-97e752111228    Sparse[float64, 0.0]
# fa8f7c8e-277f-4e71-9a5e-28b13ca93bca_5d15df3e-fa54-45d5-85c6-5e3f5b89b20e    Sparse[float64, 0.0]
# Length: 18121, dtype: object

# %%
# Because all matrices are quite sparse
data['F'].sparse.density
# Out:
# 0.004792547978964625
